# %% [markdown]
# A classification problem

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical

data = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/iris.data', header=None)
data = data.values
# Split the data into features and labels
X = data[:, :4].astype(float)
y = data[:, 4]
# Encode the class labels
encoder = LabelEncoder()
encoder.fit(y)
encoded_y = encoder.transform(y)
dummy_y = to_categorical(encoded_y)

X_train, X_test, y_train, y_test = train_test_split(X, dummy_y, test_size=0.3, random_state=42)

model = Sequential()
model.add(Dense(10, input_dim=4, activation='relu'))
model.add(Dense(3, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=50, batch_size=5, verbose=1)
loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: %.2f%%" % (accuracy * 100))
# Out:
# Epoch 1/50
# 21/21 [==============================] - 1s 2ms/step - loss: 2.0876 - accuracy: 0.0000e+00
# Epoch 2/50
# 21/21 [==============================] - 0s 2ms/step - loss: 1.8495 - accuracy: 0.0095
# Epoch 3/50
# 21/21 [==============================] - 0s 2ms/step - loss: 1.7228 - accuracy: 0.0476
# Epoch 4/50
# 21/21 [==============================] - 0s 2ms/step - loss: 1.6556 - accuracy: 0.0190
# Epoch 5/50
# 21/21 [==============================] - 0s 2ms/step - loss: 1.6079 - accuracy: 0.0286
# Epoch 6/50
# 21/21 [==============================] - 0s 2ms/step - loss: 1.5712 - accuracy: 0.1429
# Epoch 7/50
# 21/21 [==============================] - 0s 2ms/step - loss: 1.5244 - accuracy: 0.0952
# Epoch 8/50
# 21/21 [==============================] - 0s 2ms/step - loss: 1.4832 - accuracy: 0.0286
# Epoch 9/50
# 21/21 [==============================] - 0s 2ms/step - loss: 1.4433 - accuracy: 0.0381
# Epoch 10/50
# ...

# %% [markdown]
# Some methods for solving overfitting issue for a classification problem, including:
# - drop out
# - early stopping
# - regularization (L1 and L2)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import regularizers
from tensorflow.keras.utils import to_categorical

data = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/iris.data', header=None)
data = data.values

X = data[:, :4].astype(float)
y = data[:, 4]

encoder = LabelEncoder()
encoder.fit(y)
encoded_y = encoder.transform(y)
dummy_y = to_categorical(encoded_y)
X_train, X_test, y_train, y_test = train_test_split(X, dummy_y, test_size=0.3, random_state=42)
model = Sequential()
model.add(Dense(10, input_dim=4, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(Dropout(0.5))
model.add(Dense(3, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
model.fit(X_train, y_train, epochs=50, batch_size=5, verbose=1, validation_data=(X_test, y_test), callbacks=[early_stopping])
loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: %.2f%%" % (accuracy * 100))
# Out:
# Epoch 1/50
# 21/21 [==============================] - 1s 12ms/step - loss: 2.2926 - accuracy: 0.3524 - val_loss: 1.0908 - val_accuracy: 0.6222
# Epoch 2/50
# 21/21 [==============================] - 0s 4ms/step - loss: 2.0254 - accuracy: 0.3048 - val_loss: 0.9652 - val_accuracy: 0.7111
# Epoch 3/50
# 21/21 [==============================] - 0s 4ms/step - loss: 1.4430 - accuracy: 0.4286 - val_loss: 0.8937 - val_accuracy: 0.7111
# Epoch 4/50
# 21/21 [==============================] - 0s 4ms/step - loss: 1.5051 - accuracy: 0.4095 - val_loss: 0.8324 - val_accuracy: 0.7111
# Epoch 5/50
# 21/21 [==============================] - 0s 4ms/step - loss: 1.5334 - accuracy: 0.4000 - val_loss: 0.7902 - val_accuracy: 0.7111
# Epoch 6/50
# 21/21 [==============================] - 0s 4ms/step - loss: 1.2880 - accuracy: 0.4286 - val_loss: 0.7793 - val_accuracy: 0.7111
# Epoch 7/50
# ...

# %% [markdown]
# A regression problem

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense

data = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/iris.data', header=None)

X = data.iloc[:, 1:4]  # Use the second, third, and fourth columns as features
y = data.iloc[:, 0]    # Use the first column as the target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
model = Sequential()
model.add(Dense(10, input_dim=3, activation='relu'))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(X_train, y_train, epochs=50, batch_size=5, verbose=1)
loss = model.evaluate(X_test, y_test, verbose=0)
print("Mean Squared Error: %.2f" % loss)
# Out:
# Epoch 1/50
# 21/21 [==============================] - 1s 2ms/step - loss: 32.2149
# Epoch 2/50
# 21/21 [==============================] - 0s 1ms/step - loss: 28.0775
# Epoch 3/50
# 21/21 [==============================] - 0s 2ms/step - loss: 23.7944
# Epoch 4/50
# 21/21 [==============================] - 0s 2ms/step - loss: 19.6139
# Epoch 5/50
# 21/21 [==============================] - 0s 1ms/step - loss: 15.5909
# Epoch 6/50
# 21/21 [==============================] - 0s 2ms/step - loss: 11.9359
# Epoch 7/50
# 21/21 [==============================] - 0s 2ms/step - loss: 8.8527
# Epoch 8/50
# 21/21 [==============================] - 0s 2ms/step - loss: 6.3156
# Epoch 9/50
# 21/21 [==============================] - 0s 2ms/step - loss: 4.4089
# Epoch 10/50
# 21/21 [==============================] - 0s 2ms/step - loss: 3.0236
# Epoch 11/50
# 21/21 [==============================] - 0s 2ms/step - loss: 2.1253
# Epoch 12/50
# ...

# %% [markdown]
# Some methods for solving overfitting issue for a regression problem, including:
# - drop out
# - early stopping
# - regularization (L1 and L2)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.callbacks import EarlyStopping
from keras import regularizers

data = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/iris.data', header=None)

X = data.iloc[:, 1:4]  # Use the second, third, and fourth columns as features
y = data.iloc[:, 0]    # Use the first column as the target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
model = Sequential()
model.add(Dense(10, input_dim=3, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(Dropout(0.5))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
model.fit(X_train, y_train, epochs=50, batch_size=5, verbose=1, validation_data=(X_test, y_test), callbacks=[early_stopping])
loss = model.evaluate(X_test, y_test, verbose=0)
print("Mean Squared Error: %.2f" % loss)
# Out:
# Epoch 1/50
#  1/21 [>.............................] - ETA: 24s - loss: 20.0609
# WARNING:tensorflow:5 out of the last 457 calls to <function Model.make_test_function.<locals>.test_function at 0x7881546d7b50> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 21/21 [==============================] - 1s 10ms/step - loss: 28.8039 - val_loss: 26.1102
# Epoch 2/50
# 21/21 [==============================] - 0s 3ms/step - loss: 26.4115 - val_loss: 22.1570
# Epoch 3/50
# ...
